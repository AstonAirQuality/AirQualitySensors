# %% [markdown]
# # Importing and locating csv files from a specified directory

# %%
#read in varaibles from other notebook
# %store -r hashmap
print(hashmap)
# Out:
# {'18699': '..\\data\\flow\\task_177_1627319652\\sensor_18699\\sensor_measures_20210717_20210721_1.csv', '18720': '..\\data\\flow\\task_177_1627319652\\sensor_18720\\sensor_measures_20210711_20210721_1.csv', '18749': '..\\data\\flow\\task_177_1627319652\\sensor_18749\\sensor_measures_20210716_20210721_1.csv'}

# %%
# %store -r sensorIds
print(sensorIds)
# Out:
# ['18699', '18720', '18749']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import numpy as np
import matplotlib.dates as mdates

# %% [markdown]
# # Intialising the measurement dataframe

# %%
#bringing the csv to pandas dataframes
dfList = []
for snum in sensorIds:
    dfList.append(pd.read_csv(hashmap[snum],parse_dates=True, index_col="date"))

# %%
#hashmap["02:00:00:00:48:13"] #Kate/Lucy
#hashmap["02:00:00:00:48:28"] #Kate/Lucy
#hashmap["02:00:00:00:48:45"] #Riyad

# %%
#dfList = []
#bringing the csv to pandas dataframes
#dfList.append(pd.read_csv(hashmap["02:00:00:00:48:45"],parse_dates=True, index_col="date"))
#dfList.append(pd.read_csv(hashmap["02:00:00:00:48:28"],parse_dates=True, index_col="date"))
#dfList.append(pd.read_csv(hashmap["02:00:00:00:48:13"],parse_dates=True, index_col="date"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cd20ac9dee73> in <module>
#       1 dfList = []
#       2 #bringing the csv to pandas dataframes
# ----> 3 dfList.append(pd.read_csv(hashmap["02:00:00:00:48:45"],parse_dates=True, index_col="date"))
#       4 dfList.append(pd.read_csv(hashmap["02:00:00:00:48:28"],parse_dates=True, index_col="date"))
#       5 dfList.append(pd.read_csv(hashmap["02:00:00:00:48:13"],parse_dates=True, index_col="date"))
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Initial look at the data
#
# ## Station 1 Riyad
# illustrate statistiscal properties of individual columns

# %%
dfList[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2849 entries, 2021-07-19 22:05:43 to 2021-07-21 21:50:44
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          2849 non-null   int64
#  1   NO2 (ppb)          2849 non-null   int64
#  2   NO2 (Plume AQI)    2849 non-null   int64
#  3   VOC (ppb)          2849 non-null   int64
#  4   VOC (Plume AQI)    2849 non-null   int64
#  5   pm 1 (ug/m3)       2849 non-null   int64
#  6   pm 1 (Plume AQI)   2849 non-null   int64
#  7   pm 10 (ug/m3)      2849 non-null   int64
#  8   pm 10 (Plume AQI)  2849 non-null   int64
#  9   pm25 (ug/m3)       2849 non-null   int64
#  10  pm 25 (Plume AQI)  2849 non-null   int64
# dtypes: int64(11)
# memory usage: 267.1 KB

# %% [markdown]
# #

# %%
dfList[0].describe()
# Out:
#           timestamp    NO2 (ppb)  NO2 (Plume AQI)    VOC (ppb)  \
# count  2.849000e+03  2849.000000      2849.000000  2849.000000
# mean   1.626818e+09     7.518428         7.151281   148.987364
# std    4.957343e+04     7.039896         7.010020    33.777182
# min    1.626732e+09     0.000000         0.000000     0.000000
# 25%    1.626775e+09     2.000000         1.000000   132.000000
# 50%    1.626818e+09     6.000000         5.000000   144.000000
# 75%    1.626861e+09    13.000000        12.000000   163.000000
# max    1.626904e+09    53.000000        58.000000   320.000000
#
#        VOC (Plume AQI)  pm 1 (ug/m3)  pm 1 (Plume AQI)  pm 10 (ug/m3)  \
# count      2849.000000   2849.000000       2849.000000    2849.000000
# mean         11.897859      1.040365          3.065637      17.209196
# std           2.707361      0.418312          0.995906      25.240830
# min           0.000000      0.000000          0.000000       0.000000
# 25%          11.000000      1.000000          3.000000       3.000000
# 50%          12.000000      1.000000          3.000000       6.000000
# 75%          13.000000      1.000000          3.000000      22.000000
# max          25.000000     13.000000         34.000000     181.000000
#
#        pm 10 (Plume AQI)  pm25 (ug/m3)  pm 25 (Plume AQI)
# count        2849.000000   2849.000000        2849.000000
# mean           17.829765      2.656020           5.323973
# std            26.741548      1.846354           3.686445
# min             0.000000      0.000000           0.000000
# 25%             3.000000      2.000000           4.000000
# 50%             6.000000      2.000000           4.000000
# 75%            22.000000      2.000000           5.000000
# max           163.000000     22.000000          43.000000

# %% [markdown]
# ## Station 2:

# %%
dfList[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2826 entries, 2021-07-19 22:05:26 to 2021-07-21 21:55:29
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          2826 non-null   int64
#  1   NO2 (ppb)          2826 non-null   int64
#  2   NO2 (Plume AQI)    2826 non-null   int64
#  3   VOC (ppb)          2826 non-null   int64
#  4   VOC (Plume AQI)    2826 non-null   int64
#  5   pm 1 (ug/m3)       2826 non-null   int64
#  6   pm 1 (Plume AQI)   2826 non-null   int64
#  7   pm 10 (ug/m3)      2826 non-null   int64
#  8   pm 10 (Plume AQI)  2826 non-null   int64
#  9   pm25 (ug/m3)       2826 non-null   int64
#  10  pm 25 (Plume AQI)  2826 non-null   int64
# dtypes: int64(11)
# memory usage: 264.9 KB

# %%
dfList[1].describe()
# Out:
#           timestamp    NO2 (ppb)  NO2 (Plume AQI)    VOC (ppb)  \
# count  2.826000e+03  2826.000000      2826.000000  2826.000000
# mean   1.626819e+09    17.553786        17.923567   118.889950
# std    4.987693e+04    21.944470        21.433408    41.769493
# min    1.626732e+09     0.000000         0.000000     0.000000
# 25%    1.626775e+09     0.000000         0.000000    92.000000
# 50%    1.626819e+09    12.000000        11.000000   126.000000
# 75%    1.626862e+09    25.000000        25.000000   149.000000
# max    1.626905e+09   221.000000       154.000000   266.000000
#
#        VOC (Plume AQI)  pm 1 (ug/m3)  pm 1 (Plume AQI)  pm 10 (ug/m3)  \
# count      2826.000000   2826.000000       2826.000000    2826.000000
# mean          9.504954      1.405520          3.917551      27.960014
# std           3.356169      1.473695          3.570171      30.807691
# min           0.000000      0.000000          0.000000       0.000000
# 25%           7.000000      1.000000          3.000000       3.000000
# 50%          10.000000      1.000000          3.000000      17.000000
# 75%          12.000000      1.000000          3.000000      40.000000
# max          21.000000     14.000000         34.000000     172.000000
#
#        pm 10 (Plume AQI)  pm25 (ug/m3)  pm 25 (Plume AQI)
# count        2826.000000   2826.000000        2826.000000
# mean           29.766100      3.496815           6.996815
# std            34.015761      3.352900           6.692354
# min             0.000000      0.000000           0.000000
# 25%             3.000000      2.000000           4.000000
# 50%            17.000000      2.000000           4.000000
# 75%            40.000000      3.000000           7.000000
# max           158.000000     25.000000          50.000000

# %% [markdown]
# ## Station 3:

# %%
dfList[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1603 entries, 2021-07-20 06:33:29 to 2021-07-21 18:22:00
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   timestamp          1603 non-null   int64
#  1   NO2 (ppb)          1603 non-null   int64
#  2   NO2 (Plume AQI)    1603 non-null   int64
#  3   VOC (ppb)          1603 non-null   int64
#  4   VOC (Plume AQI)    1603 non-null   int64
#  5   pm 1 (ug/m3)       1603 non-null   int64
#  6   pm 1 (Plume AQI)   1603 non-null   int64
#  7   pm 10 (ug/m3)      1603 non-null   int64
#  8   pm 10 (Plume AQI)  1603 non-null   int64
#  9   pm25 (ug/m3)       1603 non-null   int64
#  10  pm 25 (Plume AQI)  1603 non-null   int64
# dtypes: int64(11)
# memory usage: 150.3 KB

# %%
dfList[2].describe()
# Out:
#           timestamp    NO2 (ppb)  NO2 (Plume AQI)    VOC (ppb)  \
# count  2.826000e+03  2826.000000      2826.000000  2826.000000
# mean   1.626819e+09    17.553786        17.923567   118.889950
# std    4.987693e+04    21.944470        21.433408    41.769493
# min    1.626732e+09     0.000000         0.000000     0.000000
# 25%    1.626775e+09     0.000000         0.000000    92.000000
# 50%    1.626819e+09    12.000000        11.000000   126.000000
# 75%    1.626862e+09    25.000000        25.000000   149.000000
# max    1.626905e+09   221.000000       154.000000   266.000000
#
#        VOC (Plume AQI)  pm 1 (ug/m3)  pm 1 (Plume AQI)  pm 10 (ug/m3)  \
# count      2826.000000   2826.000000       2826.000000    2826.000000
# mean          9.504954      1.405520          3.917551      27.960014
# std           3.356169      1.473695          3.570171      30.807691
# min           0.000000      0.000000          0.000000       0.000000
# 25%           7.000000      1.000000          3.000000       3.000000
# 50%          10.000000      1.000000          3.000000      17.000000
# 75%          12.000000      1.000000          3.000000      40.000000
# max          21.000000     14.000000         34.000000     172.000000
#
#        pm 10 (Plume AQI)  pm25 (ug/m3)  pm 25 (Plume AQI)
# count        2826.000000   2826.000000        2826.000000
# mean           29.766100      3.496815           6.996815
# std            34.015761      3.352900           6.692354
# min             0.000000      0.000000           0.000000
# 25%             3.000000      2.000000           4.000000
# 50%            17.000000      2.000000           4.000000
# 75%            40.000000      3.000000           7.000000
# max           158.000000     25.000000          50.000000

# %% [markdown]
# # Identifying null values in dataframe

# %%
dfList[0].isnull().sum()
# Out:
# timestamp            0
# NO2 (ppb)            0
# NO2 (Plume AQI)      0
# VOC (ppb)            0
# VOC (Plume AQI)      0
# pm 1 (ug/m3)         0
# pm 1 (Plume AQI)     0
# pm 10 (ug/m3)        0
# pm 10 (Plume AQI)    0
# pm25 (ug/m3)         0
# pm 25 (Plume AQI)    0
# dtype: int64

# %%
dfList[1].isnull().sum()
# Out:
# timestamp            0
# NO2 (ppb)            0
# NO2 (Plume AQI)      0
# VOC (ppb)            0
# VOC (Plume AQI)      0
# pm 1 (ug/m3)         0
# pm 1 (Plume AQI)     0
# pm 10 (ug/m3)        0
# pm 10 (Plume AQI)    0
# pm25 (ug/m3)         0
# pm 25 (Plume AQI)    0
# dtype: int64

# %%
dfList[2].isnull().sum()
# Out:
# timestamp            0
# NO2 (ppb)            0
# NO2 (Plume AQI)      0
# VOC (ppb)            0
# VOC (Plume AQI)      0
# pm 1 (ug/m3)         0
# pm 1 (Plume AQI)     0
# pm 10 (ug/m3)        0
# pm 10 (Plume AQI)    0
# pm25 (ug/m3)         0
# pm 25 (Plume AQI)    0
# dtype: int64

# %% [markdown]
# # Data Visualisation N02

# %%
fig, axs = plt.subplots(3, figsize = (16,16))
sns.boxplot(x=dfList[0]['NO2 (ppb)'], ax=axs[0])
sns.boxplot(x=dfList[1]['NO2 (ppb)'], ax=axs[1])
sns.boxplot(x=dfList[2]['NO2 (ppb)'], ax=axs[2])
    #boxplot shows one outlier between 80 and 90
# Out:
# <AxesSubplot:xlabel='NO2 (ppb)'>

# %% [markdown]
# ## Idenifying zero values
# This shows the number of "0ppb" measurements to be 187. Since the time between readings is 1 minute the "0ppb" measurements are likely outliers or bad measurements.

# %%
outliers = np.array(dfList[2]["NO2 (ppb)"])
print("There are: " + str(len(outliers[outliers == 0])) + "\n Zero values in this dataset")
print("There are: " + str(len(outliers[outliers < dfList[2].quantile(0.25)["NO2 (ppb)"]])) + "\n values below the Lower Quartile in this dataset")
print("There are: " + str(len(outliers[outliers > dfList[2].quantile(0.75)["NO2 (ppb)"]])) + "\n values above the Upper Quartile in this dataset")
# Out:
# There are: 749
#  Zero values in this dataset
# There are: 0
#  values below the Lower Quartile in this dataset
# There are: 682
#  values above the Upper Quartile in this dataset

# %% [markdown]
# # Time Series Scatter plot NO2

# %%
myTimeFormat = mdates.DateFormatter('%H:%M')

plt.style.use('fivethirtyeight')
fig, axs = plt.subplots(3, figsize = (24,20))

axs[0].set_title('Station 1: NO2 time series scatter graph')
axs[0].scatter(x = dfList[0].index, y= dfList[0]["NO2 (ppb)"])
axs[0].set_xlabel("Time")
axs[0].set_ylabel("NO2 (ppb)")
axs[0].xaxis.set_major_formatter(myTimeFormat)

axs[1].set_title('Station 2: NO2 time series scatter graph')
axs[1].scatter(x = dfList[1].index, y= dfList[1]["NO2 (ppb)"])
axs[1].set_xlabel("Time")
axs[1].set_ylabel("NO2 (ppb)")
axs[1].xaxis.set_major_formatter(myTimeFormat)

axs[2].set_title('Station 3: NO2 time series scatter graph')
axs[2].scatter(x = dfList[2].index, y= dfList[2]["NO2 (ppb)"])
axs[2].set_xlabel("Time")
axs[2].set_ylabel("NO2 (ppb)")
axs[2].xaxis.set_major_formatter(myTimeFormat)


plt.show()

# %% [markdown]
# # Data Visualisation VOC

# %%
fig, axs = plt.subplots(3, figsize = (16,16))
sns.boxplot(x=dfList[0]['VOC (ppb)'], ax=axs[0])
sns.boxplot(x=dfList[1]['VOC (ppb)'], ax=axs[1])
sns.boxplot(x=dfList[2]['VOC (ppb)'], ax=axs[2])
# Out:
# <AxesSubplot:xlabel='VOC (ppb)'>

# %% [markdown]
# ## Idenifying zero values and other outliers

# %%
outliers = np.array(dfList[1]["VOC (ppb)"])
print("There are: " + str(len(outliers[outliers == 0])) + "\n Zero values in this dataset")
print("There are: " + str(len(outliers[outliers < dfList[1].quantile(0.25)["VOC (ppb)"]])) + "\n values below the Lower Quartile in this dataset")
print("There are: " + str(len(outliers[outliers > dfList[1].quantile(0.75)["VOC (ppb)"]])) + "\n values above the Upper Quartile in this dataset")
# Out:
# There are: 20
#  Zero values in this dataset
# There are: 398
#  values below the Lower Quartile in this dataset
# There are: 375
#  values above the Upper Quartile in this dataset

# %% [markdown]
# # Time Series Scatter plot VOC

# %%
plt.style.use('fivethirtyeight')
fig, axs = plt.subplots(3, figsize = (24,20))

axs[0].set_title('Station 1: VOC time series scatter graph')
axs[0].scatter(x = dfList[0].index, y= dfList[0]["VOC (ppb)"])
axs[0].set_xlabel("Time")
axs[0].set_ylabel("VOC (ppb)")
axs[0].xaxis.set_major_formatter(myTimeFormat)

axs[1].set_title('Station 2: VOC time series scatter graph')
axs[1].scatter(x = dfList[1].index, y= dfList[1]["VOC (ppb)"])
axs[1].set_xlabel("Time")
axs[1].set_ylabel("VOC (ppb)")
axs[1].xaxis.set_major_formatter(myTimeFormat)

axs[2].set_title('Station 3: VOC time series scatter graph')
axs[2].scatter(x = dfList[2].index, y= dfList[2]["VOC (ppb)"])
axs[2].set_xlabel("Time")
axs[2].set_ylabel("VOC (ppb)")
axs[2].xaxis.set_major_formatter(myTimeFormat)

plt.show()

# %% [markdown]
# # Data resampling
#
# When there is too much data this begins to look like noise. A simple way to smooth the data is to resample the dataset into a smaller size.
#
# We can take the mean value of ober every minutes of readings as our "smoothed" average of measurements

# %%
smoothdf = df.resample('15min').mean()
smoothdf.head()
# Out:
#                         timestamp  NO2 (ppb)  NO2 (Plume AQI)   VOC (ppb)  \
# date
# 2021-07-19 22:00:00  1.626733e+09  16.000000        15.000000  127.200000
# 2021-07-19 22:15:00  1.626733e+09  15.533333        14.866667  111.133333
# 2021-07-19 22:30:00  1.626734e+09  23.733333        24.200000  122.200000
# 2021-07-19 22:45:00  1.626735e+09   6.600000         6.133333  152.000000
# 2021-07-19 23:00:00  1.626736e+09   0.600000         0.600000  168.000000
#
#                      VOC (Plume AQI)  pm 1 (ug/m3)  pm 1 (Plume AQI)  \
# date
# 2021-07-19 22:00:00        10.000000      1.000000               3.0
# 2021-07-19 22:15:00         8.866667      0.933333               2.8
# 2021-07-19 22:30:00         9.800000      1.000000               3.0
# 2021-07-19 22:45:00        12.200000      1.000000               3.0
# 2021-07-19 23:00:00        13.400000      1.000000               3.0
#
#                      pm 10 (ug/m3)  pm 10 (Plume AQI)  pm25 (ug/m3)  \
# date
# 2021-07-19 22:00:00            4.3                4.3      2.000000
# 2021-07-19 22:15:00            4.6                4.6      1.866667
# 2021-07-19 22:30:00            3.2                3.2      2.000000
# 2021-07-19 22:45:00            7.2                7.2      2.133333
# 2021-07-19 23:00:00           10.0               10.0      2.200000
#
#                      pm 25 (Plume AQI)
# date
# 2021-07-19 22:00:00           4.000000
# 2021-07-19 22:15:00           3.733333
# 2021-07-19 22:30:00           4.000000
# 2021-07-19 22:45:00           4.333333
# 2021-07-19 23:00:00           4.400000

# %%
#adding ticks to for numerical iteration over the dataset (a secondary index)
smoothdf['id'] = range(0,len(smoothdf.index.values))

model = LinearRegression().fit(smoothdf[["id"]],smoothdf[["VOC (ppb)"]])
m = model.coef_[0]
b = model.intercept_

#equation of regression line 
print ('y = ', round(m[0],2), 'x + ', round(b[0],2))
# Out:
# y =  -0.12 x +  160.27

# %%
predictions = model.predict(smoothdf[["id"]])

# making a DataFrame for the predictions
predictions = pd.DataFrame(data = predictions, index = smoothdf.index.values, columns = ['VOC Pred'])
predictions.head()
# Out:
#                        VOC Pred
# 2021-07-19 22:00:00  160.269672
# 2021-07-19 22:15:00  160.151147
# 2021-07-19 22:30:00  160.032622
# 2021-07-19 22:45:00  159.914097
# 2021-07-19 23:00:00  159.795572

# %%
joined_df = smoothdf.join(predictions, how = 'inner')
joined_df.head()
# Out:
#                         timestamp  NO2 (ppb)  NO2 (Plume AQI)   VOC (ppb)  \
# date
# 2021-07-19 22:00:00  1.626733e+09  16.000000        15.000000  127.200000
# 2021-07-19 22:15:00  1.626733e+09  15.533333        14.866667  111.133333
# 2021-07-19 22:30:00  1.626734e+09  23.733333        24.200000  122.200000
# 2021-07-19 22:45:00  1.626735e+09   6.600000         6.133333  152.000000
# 2021-07-19 23:00:00  1.626736e+09   0.600000         0.600000  168.000000
#
#                      VOC (Plume AQI)  pm 1 (ug/m3)  pm 1 (Plume AQI)  \
# date
# 2021-07-19 22:00:00        10.000000      1.000000               3.0
# 2021-07-19 22:15:00         8.866667      0.933333               2.8
# 2021-07-19 22:30:00         9.800000      1.000000               3.0
# 2021-07-19 22:45:00        12.200000      1.000000               3.0
# 2021-07-19 23:00:00        13.400000      1.000000               3.0
#
#                      pm 10 (ug/m3)  pm 10 (Plume AQI)  pm25 (ug/m3)  \
# date
# 2021-07-19 22:00:00            4.3                4.3      2.000000
# 2021-07-19 22:15:00            4.6                4.6      1.866667
# 2021-07-19 22:30:00            3.2                3.2      2.000000
# 2021-07-19 22:45:00            7.2                7.2      2.133333
# 2021-07-19 23:00:00           10.0               10.0      2.200000
#
#                      pm 25 (Plume AQI)  id    VOC Pred
# date
# 2021-07-19 22:00:00           4.000000   0  160.269672
# 2021-07-19 22:15:00           3.733333   1  160.151147
# 2021-07-19 22:30:00           4.000000   2  160.032622
# 2021-07-19 22:45:00           4.333333   3  159.914097
# 2021-07-19 23:00:00           4.400000   4  159.795572

# %%
fig = plt.figure(figsize = (24,8))
ax = fig.add_subplot(111)
ax.xaxis.set_major_locator(mdates.HourLocator(interval=3)) #set x interval to hourly
ax.xaxis.set_major_formatter(myTimeFormat) #set format hour:min

ax.plot(joined_df.index, joined_df['VOC (ppb)'], color = (0,0,0), linewidth = 4, alpha = .9, label = 'Smoothed')
ax.plot(joined_df.index, joined_df['VOC Pred'], color = (1,0,0), label = 'Prediction')
ax.set_title('Resampled data vs Linear Regression VOC')
ax.set_xlabel('Time (hours)')
ax.set_ylabel('VOC (ppb)')
ax.legend(loc='lower right')

# %% [markdown]
# # PostGreSQL in Jupyter

# %%
#store the dataframe using magic function so that we can use this in a different notebook
#%store dfList
# Out:
# Stored 'smoothdf' (DataFrame)
# Stored 'df' (DataFrame)
